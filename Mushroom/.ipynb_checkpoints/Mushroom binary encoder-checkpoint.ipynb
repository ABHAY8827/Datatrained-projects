# %% [markdown]
# # Mushroom Project
# #### Problem Statement:
# #### Data Set Information:
# #### This data set includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family (pp. 500-525). Each species is identified as definitely edible, definitely poisonous, or of unknown edibility and not recommended. This latter class was combined with the poisonous one. The Guide clearly states that there is no simple rule for determining the edibility of a mushroom; no rule like ``leaflets three, let it be'' for Poisonous Oak and Ivy.
#
# ##### Thus, in this project, you have to predict the "Class" column.
#
# ##### Note: You can find the dataset in the link below.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('mushrooms.csv')

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
from category_encoders import BinaryEncoder
bi_enc= BinaryEncoder()
df_bi=bi_enc.fit_transform(df)
df_bi.sample(5)
# Out:
#       class_0  class_1  cap-shape_0  cap-shape_1  cap-shape_2  cap-surface_0  \
# 996         1        0            0            0            1              0
# 4291        1        0            1            0            1              0
# 464         1        0            0            0            1              0
# 2773        1        0            0            0            1              0
# 6           1        0            0            1            0              0
#
#       cap-surface_1  cap-surface_2  cap-color_0  cap-color_1  ...  \
# 996               1              0            0            0  ...
# 4291              0              1            0            1  ...
# 464               1              1            0            0  ...
# 2773              1              0            0            0  ...
# 6                 0              1            0            0  ...
#
#       spore-print-color_0  spore-print-color_1  spore-print-color_2  \
# ...

# %%
# checking for correlation by heat map

# %%
corr_mat  =df_bi.corr()
#size of the canvas 
plt.figure(figsize = [25,20])
#plor the correlation matrix
sns.heatmap(corr_mat,annot = True)
plt.title('Correlation matrix')
plt.show()

# %%
df_bi.corr()
# Out:
#                class_0   class_1  cap-shape_0  cap-shape_1  cap-shape_2  \
# class_0       1.000000 -1.000000    -0.118069     0.189961    -0.065028
# class_1      -1.000000  1.000000     0.118069    -0.189961     0.065028
# cap-shape_0  -0.118069  0.118069     1.000000    -0.243846    -0.687170
# cap-shape_1   0.189961 -0.189961    -0.243846     1.000000    -0.249464
# cap-shape_2  -0.065028  0.065028    -0.687170    -0.249464     1.000000
# ...                ...       ...          ...          ...          ...
# population_1  0.349460 -0.349460    -0.070750     0.210774    -0.003454
# population_2  0.298291 -0.298291    -0.088006    -0.005127    -0.053801
# habitat_0    -0.158264  0.158264     0.151721    -0.273763     0.067158
# habitat_1     0.150304 -0.150304    -0.065094     0.247122    -0.024837
# habitat_2    -0.335370  0.335370     0.044867     0.085928     0.024706
#
#               cap-surface_0  cap-surface_1  cap-surface_2  cap-color_0  \
# ...

# %%
corr_matrix = df_bi.corr()
corr_matrix
# Out:
#                class_0   class_1  cap-shape_0  cap-shape_1  cap-shape_2  \
# class_0       1.000000 -1.000000    -0.118069     0.189961    -0.065028
# class_1      -1.000000  1.000000     0.118069    -0.189961     0.065028
# cap-shape_0  -0.118069  0.118069     1.000000    -0.243846    -0.687170
# cap-shape_1   0.189961 -0.189961    -0.243846     1.000000    -0.249464
# cap-shape_2  -0.065028  0.065028    -0.687170    -0.249464     1.000000
# ...                ...       ...          ...          ...          ...
# population_1  0.349460 -0.349460    -0.070750     0.210774    -0.003454
# population_2  0.298291 -0.298291    -0.088006    -0.005127    -0.053801
# habitat_0    -0.158264  0.158264     0.151721    -0.273763     0.067158
# habitat_1     0.150304 -0.150304    -0.065094     0.247122    -0.024837
# habitat_2    -0.335370  0.335370     0.044867     0.085928     0.024706
#
#               cap-surface_0  cap-surface_1  cap-surface_2  cap-color_0  \
# ...

# %%
corr_matrix = df_bi.corr()
corr_matrix['class_1'].sort_values(ascending=False)
# Out:
# class_1                       1.000000
# spore-print-color_1           0.725566
# odor_3                        0.686152
# stalk-surface-below-ring_0    0.573524
# ring-type_1                   0.542538
#                                 ...
# stalk-surface-below-ring_2   -0.464768
# bruises_1                    -0.501530
# gill-size_0                  -0.540024
# class_0                      -1.000000
# veil-type_0                        NaN
# Name: class_1, Length: 66, dtype: float64

# %%
df_bi['veil-type_0'].isnull().sum()
# Out:
# 0
